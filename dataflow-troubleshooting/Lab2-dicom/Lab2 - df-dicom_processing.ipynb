# %% [markdown]
# # Dicom parsing & compute goes wrong
#
# - This pipeline shows you how multiple things can go wrong and make a pipeline fail using the DICOM format
#
# - We are also using Gemini to give us an initial diagnose that in real life would need to be validated by a doctor
#
# The NIH Chest X-ray dataset consists of 100,000 de-identified images of chest x-rays in PNG format, provided by NIH Clinical Center
#
# We are using the following datasource: gs://srtt-healthcare-nih-chest-xray
#
# ### Instructions
# 1. Update the project_id, gcs_data_path, temp_location, region
# 2. We need a lot of files from this bucket gs://gcs-public-data--healthcare-nih-chest-xray/dicom/*.dcm copied into a local bucket of yours: gcs_data_path (use the cell for that)
# 3. Authenticate with your user so that you can submit your job directly from the notebook (for Colab)
#
# ### What to do
# - Try to use a few dicon files (changing the beam.create statement)
# - Check for things that don’t look right
# - Correct the missing code to have gemini do adiagnose over the image or image + meta data

# %%
# !pip install apache_beam[gcp]>=2.50
# !pip install pydicom
# !pip install pillow
# !pip install numpy
# !pip install --upgrade google-cloud-aiplatform
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.0-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 16.9 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.0
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (10.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (1.66.0)
# Collecting google-cloud-aiplatform
#   Downloading google_cloud_aiplatform-1.67.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.19.2)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (24.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.12.5)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.0.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.9.2)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform) (4.12.2)
# Requirement already satisfied: numpy<3,>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.26.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2024.8.30)
# Downloading google_cloud_aiplatform-1.67.1-py2.py3-none-any.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 46.7 MB/s eta 0:00:00
# Installing collected packages: google-cloud-aiplatform
#   Attempting uninstall: google-cloud-aiplatform
#     Found existing installation: google-cloud-aiplatform 1.66.0
#     Uninstalling google-cloud-aiplatform-1.66.0:
#       Successfully uninstalled google-cloud-aiplatform-1.66.0
# Successfully installed google-cloud-aiplatform-1.67.1

# %%
#@title Colab notebook variables { run: "auto", display-mode: "form" }
PROJECT_ID = "sfsc-srtt-shared" #@param {type:"string"}
GCS_DATA_PATH = "gs://srtt-healthcare-nih-chest-xray" #@param {type:"string"}
TEMP_LOCATION = "gs://sfsc-df/temp/" #@param {type:"string"}
REGION = "us-central1" #@param {type:"string"}

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !gcloud config set $PROJECT_ID
#copy necessary files
# !gsutil -m -u $PROJECT_ID cp gs://gcs-public-data--healthcare-nih-chest-xray/dicom/*.dcm $GCS_DATA_PATH
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000165_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000165_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000165_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000165_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000165_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000165_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000165_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000166_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000167_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000167_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000168_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000168_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000169_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000169_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000170_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000171_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000172_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000172_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000172_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000172_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000172_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000172_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000172_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000173_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000173_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000174_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000174_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000174_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000174_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000174_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000174_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000175_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000175_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000175_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000176_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000176_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000176_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000177_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000177_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000177_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000177_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000177_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000177_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000178_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000179_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000179_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000179_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000179_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000179_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000179_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000179_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000179_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000180_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000180_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000180_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000180_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_009.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_010.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_011.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_012.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_013.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_014.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_015.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_016.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_017.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_018.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_019.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_020.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_021.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_022.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_023.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_024.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_025.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_026.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_027.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_028.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_029.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_030.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_031.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_032.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_033.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_034.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_035.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_036.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_037.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_038.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_039.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_040.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_041.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_042.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_043.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_044.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_045.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_046.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_047.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_048.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_049.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_050.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_051.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_052.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_053.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_054.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_055.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_056.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_057.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_058.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_059.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_060.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_061.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_062.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_063.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_064.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000181_065.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000182_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000183_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000183_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000183_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000184_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000184_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000185_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000186_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000187_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000187_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000187_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000188_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000188_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000189_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000190_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000190_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000190_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000190_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000190_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000190_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000191_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000192_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_009.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_010.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_011.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_012.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_013.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_014.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_015.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_016.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_017.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_018.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000193_019.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000194_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000194_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000194_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000194_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000194_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000194_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000195_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000196_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000197_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000197_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000197_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000197_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000198_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000199_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000199_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000199_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000199_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000199_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000199_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000200_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000200_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000201_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000201_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000202_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000202_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000203_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000204_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000204_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000204_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000204_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000204_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000204_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000205_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000205_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000206_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000206_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000207_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000208_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000209_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000210_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000210_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_009.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_010.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_011.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_012.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_013.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_014.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_015.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_016.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_017.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_018.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_019.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_020.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_021.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_022.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_023.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_024.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_025.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_026.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_027.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_028.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_029.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_030.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_031.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_032.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_033.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_034.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_035.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_036.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_037.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_038.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_039.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_040.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_041.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_042.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000211_043.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000212_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000213_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000213_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000213_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000213_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000213_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000213_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000214_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000215_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000216_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000217_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000218_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000219_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000219_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000219_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000219_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000220_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000221_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000222_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000223_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000224_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000224_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000225_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000225_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000226_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000227_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000227_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000228_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000229_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000230_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000230_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000230_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000230_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000230_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000230_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000230_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000230_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_009.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_010.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_011.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_012.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000231_013.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000232_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000232_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000233_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000234_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000235_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000236_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000237_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000238_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000238_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000238_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000239_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000239_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000239_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000239_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000239_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000239_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000240_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000241_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000241_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000242_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000242_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000242_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000242_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000242_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000242_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000243_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000243_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000244_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000244_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000244_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000245_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000245_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000245_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_009.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_010.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_011.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_012.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_013.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_014.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_015.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_016.dcm [Content-Type=application/octet-stream]...
# \ [999 files][  999 MiB/  999 MiB]    3.8 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_017.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_018.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000246_019.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000247_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_009.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_010.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_011.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_012.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_013.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_014.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_015.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_016.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_017.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_018.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_019.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_020.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_021.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_022.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_023.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_024.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_025.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_026.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00000248_027.dcm [Content-Type=application/octet-stream]...
# ...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001466_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001467_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001468_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001469_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001470_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001471_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001471_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001471_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001471_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001471_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001471_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001472_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001472_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001473_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001473_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001473_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001473_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001473_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001473_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001473_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001474_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001475_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001476_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001477_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001478_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001479_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001480_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001480_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001481_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001481_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001482_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001482_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_009.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_010.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_011.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_012.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_013.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_014.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_015.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_016.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_017.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_018.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_019.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_020.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_021.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_022.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001483_023.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001484_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001484_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001484_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001484_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001485_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001485_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001485_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001485_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001485_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001485_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001486_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001487_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001488_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001489_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001490_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001491_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001491_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001492_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001492_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001492_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001492_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001492_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001493_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001493_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001494_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001495_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001495_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001495_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001496_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001496_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001496_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001496_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001497_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001498_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001498_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001499_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001500_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001500_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001500_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001501_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001502_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001503_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_000.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_001.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_002.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_003.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_004.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_005.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_006.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_007.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_008.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_009.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_010.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_011.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_012.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_013.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_014.dcm [Content-Type=application/octet-stream]...
# Copying gs://gcs-public-data--healthcare-nih-chest-xray/dicom/00001504_015.dcm [Content-Type=application/octet-stream]...
# Caught CTRL-C (signal 2) - exiting
# ^C

# %%
import pydicom
from PIL import Image
import apache_beam as beam
from apache_beam.io import fileio
from apache_beam.options.pipeline_options import PipelineOptions
import numpy as np
import io

import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

#Extract DICOM data
class ReadDicom(beam.DoFn):
  def __init__(self):
      print('init')
  #def start_bundle(self):
  #     print('start_bundle')
  #def finish_bundle(self):
  #     print('finish_bundle'
  def process(self, path):
      ds = pydicom.dcmread(path)
      metadata ={"patientId":ds.PatientID, "name":str(ds.PatientName)[0:5], "Patient​Sex":ds.PatientSex, "studyId":ds.StudyId, "studyDate":ds.studyDate}
      imgdata = {"patientId":ds.PatientID, "studyId":ds.StudyId, "Patient​Sex":ds.PatientSex, "img2d": ds.pixel_array.astype(float)}

      yield beam.pvalue.TaggedOutput('meta',metadata)
      yield beam.pvalue.TaggedOutput('img', imgdata )

# convert to JPEG
class ConvertImg(beam.DoFn):
  def process(self, rec):
    image_2d_scaled = (np.maximum(rec['img2d'],0) / rec['img2d'].max()) *255.0

    image_2d_scaled = np.uint8(image_2d_scaled)
    img = Image.fromarray(image_2d_scaled)
    with io.BytesIO() as buf:
      return img.save(buf, 'jpeg')


#call gemini
class CallVertexAIGeminiModel(beam.DoFn):
  m = None
  def setup(self):
     vertexai.init(project=PROJECT_ID, location=REGION)
     print("all setup")

  def process(self, filecontent):
    m = GenerativeModel(
        "gemini-1.5-flash-001",
    )

    prompt = """
    for study purpose, you are showing student how to diagnose illness by looking at chest x-rays, based on the following image could you give us a diagnose ?
    """

    img_file =  filecontent[1].read(mime_type="img/jpeg")
    contents = [Part.from_data(img_file, mime_type=="img/jpeg"), prompt]
    response = m.generate_content(contents)

    yield response.text

####nain pipeline
beam_options = PipelineOptions(
    runner='DataflowRunner',
    max_num_workers=10,
    project=PROJECT_ID,
    job_name='apple-workshop2',
    temp_location=TEMP_LOCATION,
    region=REGION
    )

with beam.Pipeline(options=beam_options) as p:
   out1 = (p | "search files" >>  beam.Create([GCS_DATA_PATH + "/*"])
          |  fileio.MatchAll()
          |  fileio.ReadMatches()
          |  "read Dicom" >> beam.ParDo(ReadDicom()).with_outputs()
   )

   #process img
   img_processed =( out1.img
                   | 'set keys img' >> beam.util.WithKeys(lambda x: x.metadata.path)
                   | 'convert to jpeg' >> beam.ParDo(ConvertImg())
   )

   #process metadata
   meta_processed =( out1.meta
                   | 'set keys meta' >> beam.util.WithKeys(lambda x: x['Patient​Sex'])
   )


   #Join the pictures & meta data to get the diagnostic
   joined_bc_bd_pv = ({'img':img_processed, 'meta': meta_processed}
                        |'Merge img & meta' >> beam.CoGroupByKey()
                        | 'display' >> beam.ParDo(print)
                      #  | 'call Gemini' >> beam.ParDo(CallVertexAIGeminiModel())

   )

#https://www.oreilly.com/online-learning/sep2024-reveal-your-deal.html?code=FALLSAVINGS24&utm_medium=email
# Out:
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'jpeg_ls'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'jpeg_ls'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'jpeg_ls'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'jpeg_ls'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'jpeg_ls'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'jpeg_ls'
# ERROR:pydicom.pixels.utils:No module named 'jpeg_ls'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'jpeg_ls'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# ERROR:pydicom.pixels.utils:No module named 'pylibjpeg'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pydicom/pixels/utils.py", line 1274, in _passes_version_check
#     module = importlib.import_module(package_name, "__version__")
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pylibjpeg'
# US1_J2KR.dcm:   0%|          | 38.0/154k [00:00<01:46, 1.45kB/s]
# MR-SIEMENS-DICOM-WithOverlays.dcm:   0%|          | 125/511k [00:00<03:04, 2.76kB/s]
# OBXXXX1A.dcm:   0%|          | 119/486k [00:00<02:48, 2.89kB/s]
# US1_UNCR.dcm:   0%|          | 226/923k [00:00<05:00, 3.07kB/s]
# color3d_jpeg_baseline.dcm:   0%|          | 1.50k/6.14M [00:00<08:43, 11.7kB/s]
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json']
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json']
# WARNING:apache_beam.options.pipeline_options:Bucket specified in temp_location has soft-delete policy enabled. To avoid being billed for unnecessary storage costs, turn off the soft delete feature on buckets that your Dataflow jobs use for temporary and staging storage. For more information, see https://cloud.google.com/storage/docs/use-soft-delete#remove-soft-delete-policy.
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json']
#   <style>
#     div.alert {
#       white-space: pre-line;
#     }
#   </style>
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div class="alert alert-info">No cache_root detected. Defaulting to staging_location gs://sfsc-df/temp/ for cache location.</div>
# init
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json']
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json']
# WARNING:apache_beam.options.pipeline_options:Bucket specified in temp_location has soft-delete policy enabled. To avoid being billed for unnecessary storage costs, turn off the soft delete feature on buckets that your Dataflow jobs use for temporary and staging storage. For more information, see https://cloud.google.com/storage/docs/use-soft-delete#remove-soft-delete-policy.
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json']
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json']
# WARNING:apache_beam.options.pipeline_options:Bucket specified in staging_location has soft-delete policy enabled. To avoid being billed for unnecessary storage costs, turn off the soft delete feature on buckets that your Dataflow jobs use for temporary and staging storage. For more information, see https://cloud.google.com/storage/docs/use-soft-delete#remove-soft-delete-policy.
# WARNING:apache_beam.options.pipeline_options:Unknown pipeline options received: -f,/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json. Ignore if flags are used for internal purposes.
# WARNING:apache_beam.options.pipeline_options:Discarding flag -f, single dash flags are not allowed.
# WARNING:apache_beam.options.pipeline_options:Unknown pipeline options received: -f,/root/.local/share/jupyter/runtime/kernel-d7391a34-c724-4977-b03e-50766db9a341.json. Ignore if flags are used for internal purposes.
# WARNING:apache_beam.options.pipeline_options:Discarding flag -f, single dash flags are not allowed.
# ERROR:apache_beam.runners.dataflow.dataflow_runner:2024-09-19T10:01:15.437Z: JOB_MESSAGE_ERROR: Traceback (most recent call last):
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 311, in _execute
#     response = task()
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 386, in <lambda>
#     lambda: self.create_worker().do_instruction(request), request)
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 656, in do_instruction
#     return getattr(self, request_type)(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 694, in process_bundle
#     bundle_processor.process_bundle(instruction_id))
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 1119, in process_bundle
#     input_op_by_transform_id[element.transform_id].process_encoded(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 237, in process_encoded
#     self.output(decoded_value)
#   File "apache_beam/runners/worker/operations.py", line 567, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 569, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 260, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1607, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined [while running '[8]: read Dicom/ParDo(ReadDicom)-ptransform-89']
#
# ERROR:apache_beam.runners.dataflow.dataflow_runner:2024-09-19T10:01:16.573Z: JOB_MESSAGE_ERROR: Traceback (most recent call last):
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 311, in _execute
#     response = task()
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 386, in <lambda>
#     lambda: self.create_worker().do_instruction(request), request)
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 656, in do_instruction
#     return getattr(self, request_type)(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 694, in process_bundle
#     bundle_processor.process_bundle(instruction_id))
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 1119, in process_bundle
#     input_op_by_transform_id[element.transform_id].process_encoded(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 237, in process_encoded
#     self.output(decoded_value)
#   File "apache_beam/runners/worker/operations.py", line 567, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 569, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 260, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1607, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined [while running '[8]: read Dicom/ParDo(ReadDicom)-ptransform-89']
#
# ERROR:apache_beam.runners.dataflow.dataflow_runner:2024-09-19T10:01:17.743Z: JOB_MESSAGE_ERROR: Traceback (most recent call last):
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 311, in _execute
#     response = task()
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 386, in <lambda>
#     lambda: self.create_worker().do_instruction(request), request)
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 656, in do_instruction
#     return getattr(self, request_type)(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 694, in process_bundle
#     bundle_processor.process_bundle(instruction_id))
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 1119, in process_bundle
#     input_op_by_transform_id[element.transform_id].process_encoded(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 237, in process_encoded
#     self.output(decoded_value)
#   File "apache_beam/runners/worker/operations.py", line 567, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 569, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 260, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1607, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined [while running '[8]: read Dicom/ParDo(ReadDicom)-ptransform-89']
#
# ERROR:apache_beam.runners.dataflow.dataflow_runner:2024-09-19T10:01:18.775Z: JOB_MESSAGE_ERROR: Traceback (most recent call last):
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 311, in _execute
#     response = task()
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 386, in <lambda>
#     lambda: self.create_worker().do_instruction(request), request)
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 656, in do_instruction
#     return getattr(self, request_type)(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 694, in process_bundle
#     bundle_processor.process_bundle(instruction_id))
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 1119, in process_bundle
#     input_op_by_transform_id[element.transform_id].process_encoded(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 237, in process_encoded
#     self.output(decoded_value)
#   File "apache_beam/runners/worker/operations.py", line 567, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 569, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 260, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1607, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined [while running '[8]: read Dicom/ParDo(ReadDicom)-ptransform-89']
#
# ERROR:apache_beam.runners.dataflow.dataflow_runner:2024-09-19T10:01:19.049Z: JOB_MESSAGE_ERROR: Workflow failed. Causes: S02:[8]: search files/Impulse+[8]: search files/FlatMap(<lambda at core.py:3903>)+[8]: search files/Map(decode)+[8]: MatchAll/ParDo(_MatchAllFn)+[8]: ReadMatches/ParDo(_ReadMatchesFn)+[8]: read Dicom/ParDo(ReadDicom)+[8]: set keys img/Map(<lambda at util.py:1054>)+[8]: convert to jpeg+[8]: Merge img & meta/CoGroupByKeyImpl/Tag[img]+[8]: Merge img & meta/CoGroupByKeyImpl/Flatten/InputIdentity+[8]: set keys meta/Map(<lambda at util.py:1054>)+[8]: Merge img & meta/CoGroupByKeyImpl/Tag[meta]+[8]: Merge img & meta/CoGroupByKeyImpl/Flatten/InputIdentity+[8]: Merge img & meta/CoGroupByKeyImpl/GroupByKey/Session/Flatten+[8]: Merge img & meta/CoGroupByKeyImpl/GroupByKey/Write failed., The job failed because a work item has failed 4 times. Look in previous log entries for the cause of each one of the 4 failures. If the logs only contain generic timeout errors related to accessing external resources, such as MongoDB, verify that the worker service account has permission to access the resource's subnetwork. For more information, see https://cloud.google.com/dataflow/docs/guides/common-errors. The work item was attempted on these workers:
#
#       Root cause: Traceback (most recent call last):
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 311, in _execute
#     response = task()
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 386, in <lambda>
# ...
# NameError: name 'pydicom' is not defined [while running '[8]: read Dicom/ParDo(ReadDicom)-ptransform-89']
#
#       Worker ID: apple-workshop2-09190257-n1v8-harness-jtqn,
#
#       Root cause: Traceback (most recent call last):
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 311, in _execute
#     response = task()
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 386, in <lambda>
#     lambda: self.create_worker().do_instruction(request), request)
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 656, in do_instruction
#     return getattr(self, request_type)(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 694, in process_bundle
#     bundle_processor.process_bundle(instruction_id))
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 1119, in process_bundle
#     input_op_by_transform_id[element.transform_id].process_encoded(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 237, in process_encoded
#     self.output(decoded_value)
#   File "apache_beam/runners/worker/operations.py", line 567, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 569, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 260, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1607, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined [while running '[8]: read Dicom/ParDo(ReadDicom)-ptransform-89']
#
#       Worker ID: apple-workshop2-09190257-n1v8-harness-jtqn
# ERROR:apache_beam.runners.dataflow.dataflow_runner:Console URL: https://console.cloud.google.com/dataflow/jobs/<RegionId>/2024-09-19_02_57_38-18244829210659342278?project=<ProjectId>
# ---------------------------------------------------------------------------
# DataflowRuntimeException                  Traceback (most recent call last)
# <ipython-input-8-60d2e0d58552> in <cell line: 72>()
#      70     )
#      71
# ---> 72 with beam.Pipeline(options=beam_options) as p:
#      73    out1 = (p | "search files" >>  beam.Create([GCS_DATA_PATH + "/*"])
#      74           |  fileio.MatchAll()
#
# /usr/local/lib/python3.10/dist-packages/apache_beam/pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     619       if not exc_type:
#     620         self.result = self.run()
# --> 621         self.result.wait_until_finish()
#     622     finally:
#     623       self._extra_context.__exit__(exc_type, exc_val, exc_tb)
#
# /usr/local/lib/python3.10/dist-packages/apache_beam/runners/dataflow/dataflow_runner.py in wait_until_finish(self, duration)
#     805         # theresolution of the issue.
#     806         _LOGGER.error(consoleUrl)
# --> 807         raise DataflowRuntimeException(
#     808             'Dataflow pipeline failed. State: %s, Error:\n%s' %
#     809             (self.state, getattr(self._runner, 'last_error_msg', None)),
#
# DataflowRuntimeException: Dataflow pipeline failed. State: FAILED, Error:
# Traceback (most recent call last):
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 311, in _execute
#     response = task()
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 386, in <lambda>
#     lambda: self.create_worker().do_instruction(request), request)
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 656, in do_instruction
#     return getattr(self, request_type)(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/sdk_worker.py", line 694, in process_bundle
#     bundle_processor.process_bundle(instruction_id))
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 1119, in process_bundle
#     input_op_by_transform_id[element.transform_id].process_encoded(
#   File "/usr/local/lib/python3.10/site-packages/apache_beam/runners/worker/bundle_processor.py", line 237, in process_encoded
#     self.output(decoded_value)
#   File "apache_beam/runners/worker/operations.py", line 567, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 569, in apache_beam.runners.worker.operations.Operation.output
#   File "apache_beam/runners/worker/operations.py", line 260, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1586, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1681, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "apache_beam/runners/common.py", line 1794, in apache_beam.runners.common._OutputHandler._write_value_to_tag
#   File "apache_beam/runners/worker/operations.py", line 263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive
#   File "apache_beam/runners/worker/operations.py", line 950, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/worker/operations.py", line 951, in apache_beam.runners.worker.operations.DoOperation.process
#   File "apache_beam/runners/common.py", line 1497, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 1607, in apache_beam.runners.common.DoFnRunner._reraise_augmented
#   File "apache_beam/runners/common.py", line 1495, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam/runners/common.py", line 687, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "apache_beam/runners/common.py", line 1671, in apache_beam.runners.common._OutputHandler.handle_process_outputs
#   File "<ipython-input-8-60d2e0d58552>", line 22, in process
# NameError: name 'pydicom' is not defined [while running '[8]: read Dicom/ParDo(ReadDicom)-ptransform-89']
